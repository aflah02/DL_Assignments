# %%
import numpy as np
from toolkit import *
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0)/charset_normalizer (2.0.10) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
x_train, y_train, x_val, y_val, x_test, y_test = load_data()

# %%
x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape
# Out:
# ((48000, 784),
#  (48000, 10),
#  (12000, 784),
#  (12000, 10),
#  (10000, 784),
#  (10000, 10))

# %%
# model = NeuralNetwork(784, (28,28), [128], 10, relu, relu_prime, 'normal_init', mse, mse_prime, 'momentum', {'gamma': 0.9})
# model.fit(x_train, y_train, x_val, y_val, epochs=10, learning_rate=0.01, batch_size=128, early_stopping=True, patience=5, verbose=True)
# print(f"Accuracy: {model.score(x_test, y_test)}")
# Out:
# Epoch: 0, Training Loss: 0.00015644338959789594, Validation Loss: 0.02427284517904286, Training Accuracy: 0.8515625, Validation Accuracy: 0.8301666666666667
# Epoch: 1, Training Loss: 0.00025881681485195933, Validation Loss: 0.021755813965415993, Training Accuracy: 0.890625, Validation Accuracy: 0.8514166666666667
# Epoch: 2, Training Loss: 0.00014905935422799006, Validation Loss: 0.022029377199665863, Training Accuracy: 0.890625, Validation Accuracy: 0.84925
# Epoch: 3, Training Loss: 0.0002785842955284464, Validation Loss: 0.02000878150098382, Training Accuracy: 0.90625, Validation Accuracy: 0.862
# Epoch: 4, Training Loss: 0.00032911925082998114, Validation Loss: 0.020517725156800073, Training Accuracy: 0.9140625, Validation Accuracy: 0.859
# Epoch: 5, Training Loss: 8.668103329112447e-05, Validation Loss: 0.019463626782203643, Training Accuracy: 0.9296875, Validation Accuracy: 0.86775
# Epoch: 6, Training Loss: 0.00025578553616035723, Validation Loss: 0.01920222757456396, Training Accuracy: 0.9140625, Validation Accuracy: 0.8695
# Epoch: 7, Training Loss: 0.0003007989384853805, Validation Loss: 0.018240037709049563, Training Accuracy: 0.9375, Validation Accuracy: 0.87425
# Epoch: 8, Training Loss: 0.00032536188148596064, Validation Loss: 0.01819187096241771, Training Accuracy: 0.9375, Validation Accuracy: 0.87625
# Epoch: 9, Training Loss: 0.00011449195048653907, Validation Loss: 0.01906979556142714, Training Accuracy: 0.9453125, Validation Accuracy: 0.8698333333333333
# Accuracy: 0.8701

# %%
# model = NeuralNetwork(784, (28,28), [128], 10, relu, relu_prime, 'normal_init', mse, mse_prime, 'nestrov_accelerated_gradient', {'gamma': 0.9})
# model.fit(x_train, y_train, x_val, y_val, epochs=10, learning_rate=0.01, batch_size=128, early_stopping=True, patience=5, verbose=True)
# print(f"Accuracy: {model.score(x_test, y_test)}")
# Out:
# Epoch: 0, Training Loss: 0.00019222230007436643, Validation Loss: 0.0228439296285066, Training Accuracy: 0.859375, Validation Accuracy: 0.8419166666666666
# Epoch: 8, Training Loss: 0.0001886908828675067, Validation Loss: 0.01766785604155991, Training Accuracy: 0.8515625, Validation Accuracy: 0.879
# Epoch: 9, Training Loss: 0.0001797095423130001, Validation Loss: 0.0175184136422031, Training Accuracy: 0.8515625, Validation Accuracy: 0.88
# Accuracy: 0.884

# %%
model = NeuralNetwork(784, (28,28), [128], 10, relu, relu_prime, 'normal_init', mse, mse_prime, 'rmsprop', {'epsilon': 1e-8, 'decay_rate': 0.9})
model.fit(x_train, y_train, x_val, y_val, epochs=10, learning_rate=0.01, batch_size=128, early_stopping=True, patience=5, verbose=True)
print(f"Accuracy: {model.score(x_test, y_test)}")

# %%
model = NeuralNetwork(784, (28,28), [128], 10, relu, relu_prime, 'normal_init', mse, mse_prime, 'adam', {'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-8})
model.fit(x_train, y_train, x_val, y_val, epochs=10, learning_rate=0.01, batch_size=128, early_stopping=True, patience=5, verbose=True)
print(f"Accuracy: {model.score(x_test, y_test)}")

# %%
# Load Relu Model
relu_zero_model = load_model("model_relu_zeros.pkl")
relu_normal_model = load_model("model_relu_normal_init.pkl")

# Load Sigmoid Model
sigmoid_zero_model = load_model("model_sigmoid_zeros.pkl")
sigmoid_normal_model = load_model("model_sigmoid_normal_init.pkl")

# %%
# Plot the training loss and validation loss for RELU
# fig size
plt.figure(figsize=(10, 6))
plt.plot(relu_zero_model.train_loss, label='relu_zero_train')
plt.plot(relu_zero_model.val_loss, label='relu_zero_val')
plt.plot(relu_normal_model.train_loss, label='relu_normal_train')
plt.plot(relu_normal_model.val_loss, label='relu_normal_val')
plt.title('Training and Validation Loss for RELU')
plt.legend()
plt.show()

# %%
# Plot the training loss and validation loss for Sigmoid
# fig size
plt.figure(figsize=(10, 6))
plt.plot(sigmoid_zero_model.train_loss, label='sigmoid_zero_train')
plt.plot(sigmoid_zero_model.val_loss, label='sigmoid_zero_val')
plt.plot(sigmoid_normal_model.train_loss, label='sigmoid_normal_train')
plt.plot(sigmoid_normal_model.val_loss, label='sigmoid_normal_val')
plt.title('Training and Validation Loss for Sigmoid')
plt.legend()
plt.show()

# %%
# Plot the training accuracy and validation accuracy for RELU
# fig size
plt.figure(figsize=(10, 6))
plt.plot(relu_zero_model.train_acc, label='relu_zero_train')
plt.plot(relu_zero_model.val_acc, label='relu_zero_val')
plt.plot(relu_normal_model.train_acc, label='relu_normal_train')
plt.plot(relu_normal_model.val_acc, label='relu_normal_val')
plt.title('Training and Validation Accuracy for RELU')
plt.legend()
plt.show()

# %%
# Plot the training accuracy and validation accuracy for Sigmoid
# fig size
plt.figure(figsize=(10, 6))
plt.plot(sigmoid_zero_model.train_acc, label='sigmoid_zero_train')
plt.plot(sigmoid_zero_model.val_acc, label='sigmoid_zero_val')
plt.plot(sigmoid_normal_model.train_acc, label='sigmoid_normal_train')
plt.plot(sigmoid_normal_model.val_acc, label='sigmoid_normal_val')
plt.title('Training and Validation Accuracy for Sigmoid')
plt.legend()
plt.show()
